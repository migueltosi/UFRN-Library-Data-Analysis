# %% [markdown]
# # 7 Days of Code - Alura: Python Pandas

# %% [markdown]
# **Challenger: [Francisco Foz](https://www.linkedin.com/in/francisco-tadeu-foz/?originalSubdomain=br)**

# %% [markdown]
# "Neste #7DaysOfCode, o seu objetivo será explorar os dados de empréstimos dos acervos do sistema de bibliotecas da UFRN.
#
# Você poderá treinar suas habilidades de manipulação, visualização e análise de dados utilizando Python Pandas."
#
# ---
#
# "In this #7DaysOfCode, your goal will be to explore the loan data from the collections of the UFRN library system.
#
# You will be able to train your data manipulation, visualization and analysis skills using Python Pandas."

# %% [markdown]
# ## Day 1 - Data Import

# %% [markdown]
# "Você trabalhará com dados apenas dos últimos 10 anos disponíveis. Por isso, importe para seu Jupyter Notebook os dados de:
#
# 1. [Empréstimos dos acervos das bibliotecas de UFRN](https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/tree/main/Dia_1-Importando_dados/Datasets/dados_emprestimos?utm_source=ActiveCampaign&utm_medium=email&utm_content=%237DaysOfCode+-+Python+Pandas+1%2F7%3A+Importação+de+dados&utm_campaign=%5BAlura+%237Days+Of+Code%5D%28Python+Pandas+-+1ª+Ed+%29+1%2F7)
# 2. [Exemplares do acervo](https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet?utm_source=ActiveCampaign&utm_medium=email&utm_content=%237DaysOfCode+-+Python+Pandas+1%2F7%3A+Importação+de+dados&utm_campaign=%5BAlura+%237Days+Of+Code%5D%28Python+Pandas+-+1ª+Ed+%29+1%2F7)"
#
#
# ---
#
# "You will work with data only from the last 10 years available. Therefore, import into your Jupyter Notebook the data from:
#
# 1. [copies from UFRN library collections](https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/tree/main/Dia_1-Importando_dados/Datasets/dados_emprestimos?utm_source=ActiveCampaign&utm_medium=email&utm_content=%237DaysOfCode+-+Python+Pandas+1%2F7%3A+Importação+de+dados&utm_campaign=%5BAlura+%237Days+Of+Code%5D%28Python+Pandas+-+1ª+Ed+%29+1%2F7)
# 2. [Exemplars from the collection](https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet?utm_source=ActiveCampaign&utm_medium=email&utm_content=%237DaysOfCode+-+Python+Pandas+1%2F7%3A+Importação+de+dados&utm_campaign=%5BAlura+%237Days+Of+Code%5D%28Python+Pandas+-+1ª+Ed+%29+1%2F7)"

# %%
import pandas as pd
import numpy as np

# %%
i = 20
year_filename = ['20201']
for n in range(0,10):
  i -= 1
  year_filename.append('20' + str(i) + '1')
  year_filename.append('20' + str(i) + '2')

# %%
dataframes = []

for i in year_filename:
  year = ''.join(list(i)[:-1])

  df = pd.read_csv(f'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-{i}.csv', sep=',')
  df['Ano'] = year

  dataframes.append(df)

# %%
merged_df = pd.concat(dataframes).sort_values('Ano')

# %%
copies = merged_df

# %%
copies.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario    Ano
# 709704         2006021442     2010/01/17 18:56:43.923000000  2010/01/04 09:58:46.522000000  2010/02/01 13:59:02.528000000  2.008010e+09        ALUNO DE GRADUAÇÃO      2010    7
# 709705         2009032168     2010/01/17 18:56:43.909000000  2010/01/04 09:58:46.549000000  2010/01/20 13:14:34.464000000  2.008010e+09        ALUNO DE GRADUAÇÃO      2010    7
# 709698         2009047725     2010/01/18 14:44:41.163000000  2010/01/04 09:21:19.099000000  2010/02/02 12:02:38.444000000  2.009047e+09        ALUNO DE GRADUAÇÃO      2010    3
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO  2010    2
# ...

# %%
copies = copies.drop_duplicates()

# %%
copies.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario    Ano
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO  2010    1
# 2336122        2011033079     2016/11/21 02:01:58.488000000  2016/11/10 17:00:12.989000000  2016/12/02 14:21:49.000000000  2.016023e+09        ALUNO DE GRADUAÇÃO      2016    1
# 2336103        2014085936     2016/11/25 19:25:36.215000000  2016/11/10 16:54:52.447000000  2016/12/13 14:30:52.000000000  2.014047e+09        ALUNO DE GRADUAÇÃO      2016    1
# 2336104        2011027960     2016/11/23 17:27:54.642000000  2016/11/10 16:55:17.956000000  2016/11/28 10:32:38.000000000  2.016083e+09        ALUNO DE GRADUAÇÃO      2016    1
# ...

# %% [markdown]
# Reading Apache Parquet

# %%
collections = pd.read_parquet('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet')

# %%
collections
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %%
dataframes = [copies, collections]
merged_df = collections.merge(copies)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2072522 entries, 0 to 2072521
# Data columns (total 14 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_exemplar           int64
#  1   codigo_barras         object
#  2   colecao               object
#  3   biblioteca            object
#  4   status_material       object
#  5   localizacao           int64
#  6   registro_sistema      int64
#  7   id_emprestimo         int64
#  8   data_renovacao        object
#  9   data_emprestimo       object
#  10  data_devolucao        object
#  11  matricula_ou_siape    float64
#  12  tipo_vinculo_usuario  object
#  13  Ano                   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 237.2+ MB

# %%
merged_df.sample(10)
# Out:
#          id_exemplar codigo_barras            colecao  \
# 277926       1245909    2016025825  Acervo Circulante
# 1180834       936746    2011034183  Acervo Circulante
# 636471        225130    2007024910  Acervo Circulante
# 939134        283316    2009054922  Acervo Circulante
# 299305        141350       S019387  Acervo Circulante
# 686924        241273    2007009744  Acervo Circulante
# 1175221      1038496    2013001335  Acervo Circulante
# 115523         60912       L163121  Acervo Circulante
# 643436        781200    2010018007  Acervo Circulante
# 962663        287281    2009061613  Acervo Circulante
#
#                                                 biblioteca status_material  \
# 277926                      Biblioteca Central Zila Mamede         REGULAR
# 1180834                     Biblioteca Central Zila Mamede         REGULAR
# 636471                      Biblioteca Central Zila Mamede         REGULAR
# ...

# %% [markdown]
# ## Day 2 - Data cleaning

# %% [markdown]
# "Você irá iniciar a limpeza e atribuir mais contexto aos seus dados para depois aprofundar-se nas análises"
#
# ---
#
#
# "You'll start cleaning up and giving more context to your data, then dig deeper into analytics."

# %% [markdown]
# "Crie uma nova coluna com os valores da localização, para refletir a respectiva classe geral na CDU."
#
#
# ---
#
# "Create a new column with location values ​​to reflect the respective overall class in the CDU."

# %% [markdown]
# "Você precisará ainda excluir alguns dados e modificar outros."
#
# ---
#
# "You will still need to delete some data and modify others."

# %%
merged_df.columns
# Out:
# Index(['id_exemplar', 'codigo_barras', 'colecao', 'biblioteca',
#        'status_material', 'localizacao', 'registro_sistema', 'id_emprestimo',
#        'data_renovacao', 'data_emprestimo', 'data_devolucao',
#        'matricula_ou_siape', 'tipo_vinculo_usuario', 'Ano'],
#       dtype='object')

# %%
df = merged_df[['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo', 'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario', 'Ano', 'id_exemplar', 'colecao', 'biblioteca', 'status_material', 'localizacao']]

# %%
def map_cdu_classification(value):
    if 0 <= value < 100:
        return 'Generalidades. Ciência e conhecimento'
    elif 100 <= value < 200:
        return 'Filosofia e psicologia'
    elif 200 <= value < 300:
        return 'Religião'
    elif 300 <= value < 400:
        return 'Ciências sociais'
    elif 400 <= value < 500:
        return 'Classe vaga. Provisoriamente não ocupada'
    elif 500 <= value < 600:
        return 'Matemática e ciências naturais'
    elif 600 <= value < 700:
        return 'Ciências aplicadas'
    elif 700 <= value < 800:
        return 'Belas artes'
    elif 800 <= value < 900:
        return 'Linguagem. Língua. Linguística'
    elif 900 <= value < 1000:
        return 'Geografia. Biografia. História'
    else:
        return ''

df['CDU'] = df[df['localizacao'].notnull()]['localizacao'].astype(int).map(map_cdu_classification)

# %%
df['matricula_ou_siape'] = df['matricula_ou_siape'].astype(str)

# %%
df
# Out:
#          id_emprestimo                codigo_barras  \
# 0               818501  L000133_11/05/2018 08:57:56
# 1              2037061                      L000154
# 2              1212301  L000267_14/07/2017 09:31:00
# 3               775420                      L144235
# 4               800617                      L144235
# ...                ...                          ...
# 2072517        1749057                      L113134
# 2072518        1807999                      L113134
# 2072519        1839233                      L113134
# 2072520        1663568                      L113134
# 2072521        1692686                      L113134
#
#                         data_renovacao                data_emprestimo  \
# 0                                  NaN  2010/08/17 17:00:04.440000000
# 1        2015/08/24 21:55:47.110000000  2015/08/03 10:39:42.972000000
# 2                                  NaN  2012/03/30 14:35:52.264000000
# ...

# %%
df.sample(10)
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 1207152        2393222    2010094581  2016/04/03 19:59:09.085000000
# 1748483        2316899    2013070592                            NaN
# 1180898        2464695    2011034182                            NaN
# 1379741        1193135    2011035217                            NaN
# 1538641        1399541    2012008047  2013/01/11 09:59:36.173000000
# 839191         1154790    2009005283  2012/02/06 18:25:29.138000000
# 1535393        1936830    2012021650                            NaN
# 971829         1369533    2010058624                            NaN
# 619369          952282    2009045391                            NaN
# 73675          1394093       L186396                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 1207152  2016/03/17 13:12:49.303000000  2016/04/26 18:16:49.000000000
# 1748483  2016/10/11 09:08:25.915000000  2016/10/17 10:50:50.000000000
# ...

# %% [markdown]
# ## Day 3 - Exploratory Data Analysis and DateTime

# %% [markdown]
# A diretoria da biblioteca gostaria de entender se a quantidade de empréstimos está diminuindo, aumentando ou permanecendo igual ao decorrer dos últimos anos.
#
#
# ---
#
# The library board would like to understand whether the amount of lending is decreasing, increasing, or staying the same over the last few years.

# %% [markdown]
# Além do gerenciamento anual das atividades, a diretoria também necessita que seja planejada uma programação diária das atividades. Por este motivo, verifique quais foram os horários com maior quantidade de empréstimos ao longo de um dia inteiro.
#
# ---
#
# In addition to the annual management of activities, the board also needs a daily schedule of activities to be planned. For this reason, check which were the times with the highest amount of borrowed copies over the course of a whole day.

# %% [markdown]
# A diretoria também gostaria de gerenciar melhor os recursos humanos da biblioteca de acordo com a demanda de trabalho existente.
#
# Há uma suspeita interna de que os meses com maior número de exemplares emprestados sejam março e setembro, mas não foi realizada uma análise real sobre isso.
#
# Portanto, gere uma tabela com a quantidade total de exemplares emprestados por mês e descubra quais meses são os que possuem a maior quantidade de empréstimos realizados. Plote um gráfico de linhas.
#
# ---
#
#
# The board would also like to better manage the library's human resources in line with existing work demand.
#
# There is an internal suspicion that the months with the highest number of borrowed copies are March and September, but no real analysis was carried out on this.
#
# Therefore, generate a table with the total number of copies borrowed per month and find out which months have the highest number of borrowed copies made. Plot a line graph.

# %%
# Setting up graph settings
import seaborn as sns

sns.set_theme(context='notebook',
              style='darkgrid',
              palette='deep',
              font_scale=1.3,
              rc={"figure.figsize":(15,8)})

# %%
loans_size = len(df['id_emprestimo'].drop_duplicates())
loans_size
# Out:
# 2068724

# %%
copies_size = len(df)
copies_size
# Out:
# 2072522

# %%
copies_date = pd.DataFrame(df['data_emprestimo'].value_counts()).reset_index()
copies_date.columns = ['data', 'quantidade']
copies_date['data'] = pd.to_datetime(copies_date['data'])
copies_date['ano'] = copies_date['data'].dt.year
copies_date['mes'] = copies_date['data'].dt.month
copies_date['dia'] = copies_date['data'].dt.day
copies_date['horario'] = copies_date['data'].dt.hour
copies_date
# Out:
#                            data  quantidade   ano  mes  dia  horario
# 0       2015-06-10 18:51:56.994           3  2015    6   10       18
# 1       2014-01-28 14:49:50.505           3  2014    1   28       14
# 2       2014-05-12 09:56:18.787           3  2014    5   12        9
# 3       2014-07-14 15:35:51.822           3  2014    7   14       15
# 4       2015-06-02 17:56:18.917           3  2015    6    2       17
# ...                         ...         ...   ...  ...  ...      ...
# 2068686 2010-11-25 16:11:52.704           1  2010   11   25       16
# 2068687 2010-03-08 12:14:33.586           1  2010    3    8       12
# 2068688 2018-08-31 08:00:21.556           1  2018    8   31        8
# 2068689 2018-10-17 13:38:24.199           1  2018   10   17       13
# 2068690 2014-02-19 08:45:53.369           1  2014    2   19        8
#
# [2068691 rows x 6 columns]

# %%
copies_by_year = copies_date[['ano', 'quantidade']].groupby('ano').sum()
copies_by_year
# Out:
#       quantidade
# ano
# 2010      161394
# 2011      196390
# 2012      221365
# 2013      234749
# 2014      219189
# 2015      213582
# 2016      215900
# 2017      218462
# 2018      194080
# 2019      171801
# 2020       25610

# %%
ax = sns.lineplot(data = copies_by_year, x = 'ano', y = 'quantidade')
ax.set_title('Número de exemplares emprestados em função do ano de 2010 a 2020 | Number of borrowed copies according to the year 2010 to 2020')
ax = ax

# %% [markdown]
# Nota-se uma notável queda no número dos exemplares emprestados, principalmente a partir de 2017 - 2020. O pico foi entre 2012 e 2014.
#
# *(OBS: foram coletados somente os dados do primeiro semestre de
# 2020, portanto, tal ano possui uma queda menor do que a representada pelo gráfico)*
#
# ---
#
# There is a notable drop in the number of borrowed copies, especially from 2017 - 2020. The peak was between 2012 and 2014.
#
# *(NOTE: only data from the first half of
# 2020, therefore, that year has a smaller drop than that represented by the graph)*

# %%
from datetime import datetime

# %%
copies_by_month = copies_date[['mes', 'quantidade']].groupby('mes').sum()
copies_by_month
# Out:
#      quantidade
# mes
# 1         67514
# 2        210200
# 3        252185
# 4        208725
# 5        202530
# 6        138123
# 7        123790
# 8        232793
# 9        208234
# 10       188410
# 11       164222
# 12        75796

# %%
ax = sns.lineplot(data = copies_by_month, x = 'mes', y = 'quantidade')
ax.set_title('Número de exemplares emprestados em função dos meses do ano | Number of borrowed copies according to the months of the year')
ax = ax

# %% [markdown]
# É evidente a recaída dos exemplares emprestados no mês de Julho, Dezembro e Janeiro, principalmente; tanto quanto as altas nos meses de Março e Agosto.
#
# Tal fator remete aos rumores, que acertaram em março como alta dos exemplares emprestados, mas falharam por um mês ao dizer que setembro era o segundo maior mês de alta.
#
# Sendo assim, deve-se buscar a exerção de atividades que não sejam de atendimento ao usuário e a programação de férias dos colaboradores nos meses 1, 7 e 12.
#
#
# ---
#
# It is evident the relapse of borrowed copies in July, December and January, mainly; as much as the highs in the months of March and August.
#
# This factor refers to the rumors, which were right in March as a rise in borrowed copies, but failed for a month when saying that September was the second biggest month of rise.
#
# Therefore, one should seek to carry out activities that are not user service and schedule vacations for employees in months 1, 7 and 12.

# %%
copies_by_time = copies_date[['horario', 'quantidade']].groupby('horario').sum()
copies_by_time
# Out:
#          quantidade
# horario
# 0                17
# 6                14
# 7             18777
# 8            103416
# 9            131273
# 10           185839
# 11           180048
# 12           148754
# 13           126987
# 14           150876
# 15           166672
# 16           210655
# 17           185340
# 18           182520
# 19           102129
# 20           127716
# 21            51191
# 22              247
# 23               51

# %%
ax = sns.lineplot(data = copies_by_time, x = 'horario', y = 'quantidade')
ax.set_title('Número de exemplares emprestados em função dos horários do dia | Number of borrowed copies according to time of day')
ax = ax

# %% [markdown]
# Quase não há exemplares emprestados de livros antes das 7 e depois das 21.
#
# O horário de pico é das 10 às 11 e das 16 (maior) até às 18, com pico relativo as 20.
#
# Dentre os outros, horários de baixa são das 7 às 9, das 12 às 13, 19 às 21, relativamente.
#
# ---
#
# There are almost no book borrowed copies before 7 am and after 9 pm.
#
# Peak times are from 10 am to 11 am and from 4 pm (highest) to 6 pm, with a relative peak at 8 pm.
#
# Among the others, off hours are from 7am to 9am, from 12am to 1pm, from 7pm to 9pm, relatively.

# %% [markdown]
# ## Day 4 - Exploratory Data Analysis and Categorical Variables

# %%
df
# Out:
#          id_emprestimo                codigo_barras  \
# 0               818501  L000133_11/05/2018 08:57:56
# 1              2037061                      L000154
# 2              1212301  L000267_14/07/2017 09:31:00
# 3               775420                      L144235
# 4               800617                      L144235
# ...                ...                          ...
# 2072517        1749057                      L113134
# 2072518        1807999                      L113134
# 2072519        1839233                      L113134
# 2072520        1663568                      L113134
# 2072521        1692686                      L113134
#
#                         data_renovacao                data_emprestimo  \
# 0                                  NaN  2010/08/17 17:00:04.440000000
# 1        2015/08/24 21:55:47.110000000  2015/08/03 10:39:42.972000000
# 2                                  NaN  2012/03/30 14:35:52.264000000
# ...

# %%
categorical_df = df[['tipo_vinculo_usuario', 'biblioteca', 'colecao', 'CDU']]
def create_categorical_df(categorical_value):
  categorical_value = str(categorical_value)
  by_categorical = (categorical_df[f'{categorical_value}'].value_counts()).reset_index()

  by_categorical.columns = [f'{categorical_value}', 'quantidade']
  by_categorical['percentual'] = (((by_categorical['quantidade'] / by_categorical['quantidade'].sum())*100).round(2)).astype('string') + '%'
  return by_categorical

# %%
by_user_link_type = create_categorical_df('tipo_vinculo_usuario')
by_library = create_categorical_df('biblioteca')
by_colecao = create_categorical_df('colecao')
by_cdu = create_categorical_df('CDU')

# %%
by_user_link_type
# Out:
#               tipo_vinculo_usuario  quantidade percentual
# 0               ALUNO DE GRADUAÇÃO     1612324      77.8%
# 1           ALUNO DE PÓS-GRADUAÇÃO      302541      14.6%
# 2                          DOCENTE       70981      3.42%
# 3  SERVIDOR TÉCNICO-ADMINISTRATIVO       32184      1.55%
# 4              ALUNO MÉDIO/TÉCNICO       28029      1.35%
# 5                  DOCENTE EXTERNO       23949      1.16%
# 6                  USUÁRIO EXTERNO        2509      0.12%
# 7                           OUTROS           5       0.0%

# %% [markdown]
#   É nítido que os alunos de graduação são de longe os que fazem empréstimo de mais exemplares (78%), com alunos de pós-graduação muito abaixo, em segundo lugar (14%), sendo a somatória de todos os outros alunos correspondente a 8% dos exemplares emprestados, somente.
#
# ---
#
# It is clear that undergraduate students are by far the ones who borrow the most copies (78%), with postgraduate students far below, in second place (14%), with the sum of all other students corresponding to 8 % of copies borrowed, only.

# %%
by_library
# Out:
#                                            biblioteca  quantidade percentual
# 0                      Biblioteca Central Zila Mamede     1426122     68.81%
# 1   Biblioteca Setorial do Centro Ciências da Saúd...      118614      5.72%
# 2   Biblioteca Setorial da Faculdade de Ciências d...       77609      3.74%
# 3   Biblioteca Setorial Prof. Alberto Moreira Camp...       66447      3.21%
# 4   Biblioteca Setorial Profª. Maria Lúcia da Cost...       61478      2.97%
# 5   Biblioteca Setorial Bertha Cruz Enders - ­Esco...       46040      2.22%
# 6   Biblioteca Setorial do Centro de Ciências Huma...       40744      1.97%
# 7   Biblioteca Setorial Dr. Paulo Bezerra - EMCM/R...       32097      1.55%
# 8   Biblioteca Setorial Profª. Maria José Mamede G...       29089       1.4%
# 9   Biblioteca Setorial Prof. Rodolfo Helinski - E...       27219      1.31%
# 10  Biblioteca Setorial Prof. Francisco Gurgel De ...       26923       1.3%
# ...

# %% [markdown]
# Se destaca em detrimento das demais a Biblioteca Central Zila Mamede, que compõem mais da metade (68%) dos exemplares emprestados.
#
# ---
#
# The Zila Mamede Central Library stands out to the detriment of the others, making up more than half (68%) of the borrowed copies.

# %%
by_colecao
# Out:
#                                   colecao  quantidade percentual
# 0                       Acervo Circulante     2053120     99.06%
# 1                              Multimeios        7954      0.38%
# 2                             Monografias        4021      0.19%
# 3                            Dissertações        2406      0.12%
# 4                     Obras de Referência        1954      0.09%
# 5            Publicações de Autores do RN         866      0.04%
# 6                     Publicações da UFRN         764      0.04%
# 7                                   Teses         714      0.03%
# 8                                Folhetos         271      0.01%
# 9   Necessidades Educacionais Específicas         130      0.01%
# 10                     Trabalho Acadêmico         115      0.01%
# 11                                Eventos         101       0.0%
# 12                    Coleção Mossoroense          44       0.0%
# ...

# %% [markdown]
# Os exemplares emprestados são em 99% da coleção "Acervo Circulante", o que é um fator de extrema relevância ao cálculo de demanda. Em segundo e terceiro lugar estão as coleções "Multimeios" e "Dissertações", compondo 0.6% juntas.
#
# ---
#
# 99 of the copies are borrowed from the "Acervo Circulante" collection, which is an extremely important factor when calculating demand. In second and third place are the "Multimeios" and "Dissertação" collections, comprising 0.6% together.

# %%
by_cdu
# Out:
#                                      CDU  quantidade percentual
# 0                     Ciências aplicadas     1425473     68.78%
# 1                       Ciências sociais      369536     17.83%
# 2         Matemática e ciências naturais       68744      3.32%
# 3  Generalidades. Ciência e conhecimento       62521      3.02%
# 4                               Religião       62295      3.01%
# 5                 Filosofia e psicologia       60563      2.92%
# 6         Geografia. Biografia. História        7989      0.39%
# 7                            Belas artes        7911      0.38%
# 8         Linguagem. Língua. Linguística        7490      0.36%

# %% [markdown]
# De longe o tipo de exemplar mais emprestado, dentre os do CDU, é o de "Ciências aplicadas", referente à 69% dos exemplares emprestados. Em segundo lugar, com 18% está "Ciências sociais" e, em terceiro, com 3%, está "Matemática e ciências naturais"
#
# ---
#
# By far the most borrowed type of copy, among those from the CDU, is "Applied Sciences", corresponding to 69% of the borrowed copies. Second with 18% is "Social Science" and third with 3% is "Mathematics and Natural Science"

# %% [markdown]
# ## Day 5 - Exploratory Data Analysis and Boxplot

# %% [markdown]
# Você vai fazer dois recortes em seus dados para entender como eles se distribuíram ao decorrer desses anos e, desta forma, possa trazer inferências para levar à diretoria da biblioteca, a fim de que eles possam tomar decisões para o ano atual.
#
# Para isso, você vai avaliar dentre os alunos de graduação e pós graduação a distribuição de empréstimos mensais por ano realizados entre 2010 e 2020 da coleção que tiver a maior frequência de empréstimos.
#
# Plote um gráfico para cada tipo de usuário.
# Tenha um boxplots para cada ano e analise o que ocorreu.
#
# O que está ocorrendo ao decorrer do tempo? Houve algum ano ou anos em específico que te chamaram atenção para alguma diferença? Quais as maiores diferenças entre os empréstimos para os alunos de graduação e pós graduação?
#
# ---
#
# You will make two cuts in your data to understand how they were distributed over these years and, in this way, you can bring inferences to take to the library board, so that they can make decisions for the current year.
#
# To do this, you will evaluate, among undergraduate and graduate students, the distribution of monthly loans per year taken between 2010 and 2020 from the collection that has the highest frequency of loans.
#
# Plot a graph for each type of user.
# Have a boxplot for each year and analyze what happened.
#
# What is happening over time? Was there a specific year or years that drew your attention to a difference? What are the biggest differences between undergraduate and graduate student loans?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def create_boxplot(data,x,y,title=''):

  sns.set_theme(style="darkgrid", palette='Blues',font_scale=1.3)
  plt.figure(figsize=(16,10))
  ax = sns.boxplot(y= y, x= x, data= data)
  ax.set_title(title)
  ax = ax

# %%
alunos_graduacao = df.query('tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
alunos_graduacao.colecao.value_counts()
# Out:
# Acervo Circulante                        1600155
# Multimeios                                  4652
# Monografias                                 3572
# Dissertações                                1152
# Obras de Referência                         1047
# Publicações de Autores do RN                 595
# Publicações da UFRN                          466
# Teses                                        245
# Folhetos                                     180
# Trabalho Acadêmico                            81
# Necessidades Educacionais Específicas         73
# Eventos                                       57
# Coleção Mossoroense                           17
# Coleção Zila Mamede                           15
# Literatura de Cordel                          11
# Obras Raras                                    6
# Name: colecao, dtype: int64

# %%
alunos_graduacao_acervo_circulante = pd.DataFrame(alunos_graduacao.query('colecao == "Acervo Circulante"'))
alunos_graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(alunos_graduacao_acervo_circulante['data_emprestimo'])
alunos_graduacao_acervo_circulante['ano'] = alunos_graduacao_acervo_circulante['data_emprestimo'].dt.year
alunos_graduacao_acervo_circulante['mes'] = alunos_graduacao_acervo_circulante['data_emprestimo'].dt.month
alunos_graduacao_acervo_circulante = alunos_graduacao_acervo_circulante[['ano','mes']]
alunos_graduacao_acervo_circulante = alunos_graduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
alunos_graduacao_acervo_circulante
# Out:
#       ano  mes  quantidade
# 0    2012    3       22797
# 1    2015    3       22483
# 2    2013    4       21853
# 3    2017    3       21735
# 4    2016    3       21692
# ..    ...  ...         ...
# 118  2016    1        2670
# 119  2019    1        2276
# 120  2019   12        1980
# 121  2020    1        1781
# 122  2011    1         809
#
# [123 rows x 3 columns]

# %%
create_boxplot(alunos_graduacao_acervo_circulante, 'ano', 'quantidade', title= 'Distribuição dos empréstimos mensais realizados pelos alunos de graduação ao longo dos anos de 2010 a 2020 | Distribution of monthly loans taken out by undergraduate students over the years 2010 to 2020')

# %% [markdown]
# Nota-se, de 2010 a 2013, aumento das medianas, que se mantém constante até decair do ano de 2017 a 2020.
#
# Os quartis superiores aumentam de 2010 a 2016, decaindo em 2017 até 2020.
#
# Os quartis inferiores aumentam de 2010 a 2013, decai muito em 2014, mantêm-se constante em 2015 e 2016, diminuem em 2017, crescendo e mantendo-se constante de 2018 a 2020
#
# Em proporcionalidade, nota-se que os anos onde os empréstimos mensais mostraram-se mais constantes foram os anos de 2014, 2015 e 2017. Menos constantes de 2010 a 2013 e 2018 a 2020, principalmente.
#
#
# ---
#
# It is noted, from 2010 to 2013, an increase in the medians, which remains constant until it declines from 2017 to 2020.
#
# The top quartiles increase from 2010 to 2016, decreasing from 2017 to 2020.
#
# The lower quartiles increase from 2010 to 2013, decline a lot in 2014, remain constant in 2015 and 2016, decrease in 2017, increase and remain constant from 2018 to 2020
#
# In proportionality, it is noted that the years in which monthly loans were more constant were the years 2014, 2015 and 2017. Less constant from 2010 to 2013 and 2018 to 2020, mainly.

# %%
alunos_pos_graduacao = df.query('tipo_vinculo_usuario == "ALUNO DE PÓS-GRADUAÇÃO"')
alunos_pos_graduacao.colecao.value_counts()
# Out:
# Acervo Circulante                        299201
# Dissertações                                934
# Obras de Referência                         700
# Multimeios                                  559
# Teses                                       367
# Monografias                                 278
# Publicações de Autores do RN                204
# Publicações da UFRN                         121
# Folhetos                                     60
# Necessidades Educacionais Específicas        30
# Eventos                                      26
# Coleção Mossoroense                          23
# Trabalho Acadêmico                           23
# Coleção Zila Mamede                          11
# Literatura de Cordel                          4
# Name: colecao, dtype: int64

# %%
alunos_pos_graduacao_acervo_circulante = pd.DataFrame(alunos_pos_graduacao.query('colecao == "Acervo Circulante"'))
alunos_pos_graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(alunos_pos_graduacao_acervo_circulante['data_emprestimo'])
alunos_pos_graduacao_acervo_circulante['ano'] = alunos_pos_graduacao_acervo_circulante['data_emprestimo'].dt.year
alunos_pos_graduacao_acervo_circulante['mes'] = alunos_pos_graduacao_acervo_circulante['data_emprestimo'].dt.month
alunos_pos_graduacao_acervo_circulante = alunos_pos_graduacao_acervo_circulante.loc[:,['ano','mes']]
alunos_pos_graduacao_acervo_circulante = alunos_pos_graduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
alunos_pos_graduacao_acervo_circulante
# Out:
#       ano  mes  quantidade
# 0    2015    3        3927
# 1    2017    8        3837
# 2    2017    3        3722
# 3    2016    3        3711
# 4    2016    8        3662
# ..    ...  ...         ...
# 119  2020    1        1143
# 120  2010    1        1105
# 121  2019   12        1069
# 122  2011    1         465
# 123  2020    6           2
#
# [124 rows x 3 columns]

# %%
create_boxplot(alunos_pos_graduacao_acervo_circulante, 'ano', 'quantidade', title= 'Distribuição dos empréstimos mensais realizados pelos alunos de pós-graduação ao longo dos anos de 2010 a 2020 | Distribution of monthly loans taken out by postgraduate students over the years 2010 to 2020')

# %% [markdown]
# As medianas aumentam de 2010 a 2012, mantêm-se constante até 2017 e decaem de 2018 a 2020
#
# Os quartis superiores diminuem de 2010 a 2013, aumentam em 2016, se mantêm constante em 2017 até 2020.
#
# Os quartis inferiores diminuem de 2010 a 2012, mantêm-se constante até 2014, (2015 diminuem muito, 2016 aumentam muito), depois se mantêm constante de 2017 a 2020, com decaída em 2019.
#
# Em proporcionalidade, os empréstimos mensais mostram-se mais constantes nos anos de (principalmente 2016 e 2017) e consideravelmente 2011 a 2013.
#
# ---
#
# The medians increase from 2010 to 2012, remain constant until 2017 and decrease from 2018 to 2020
#
# The upper quartiles decrease from 2010 to 2013, increase in 2016, remain constant in 2017 until 2020.
#
# The lower quartiles decrease from 2010 to 2012, remain constant until 2014, (2015 decrease a lot, 2016 increase a lot), then remain constant from 2017 to 2020, with a decrease in 2019.
#
# In proportionality, monthly loans are more constant in the years (mainly 2016 and 2017) and considerably from 2011 to 2013.

# %% [markdown]
# ## Day 6 - JSON, Excel and Pivot_table

# %% [markdown]
# Você precisará calcular a quantidade de empréstimos realizados entre 2015 e 2020 por cada curso de graduação que passará pela avaliação.
#
# ---
#
# You will need to calculate the amount of loans taken between 2015 and 2020 for each degree that will undergo the assessment.

# %%
excel_table = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx', sheet_name='Até 2010', skiprows=1)
excel_table
# Out:
#       Número da matrícula     Tipo de vinculo  \
# 0            1.900017e+08  ALUNO DE GRADUAÇÃO
# 1            1.990145e+08  ALUNO DE GRADUAÇÃO
# 2            1.997357e+08  ALUNO DE GRADUAÇÃO
# 3            1.998124e+08  ALUNO DE GRADUAÇÃO
# 4            1.998237e+08  ALUNO DE GRADUAÇÃO
# ...                   ...                 ...
# 7721         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7722         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7723         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7724         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7725         2.009075e+09  ALUNO DE GRADUAÇÃO
#
#                                       Curso
# 0                                MATEMÁTICA
# 1                       CIÊNCIAS BIOLÓGICAS
# 2                                MATEMÁTICA
# 3                                    LETRAS
# 4                                  ECOLOGIA
# ...                                     ...
# 7721                        BIBLIOTECONOMIA
# 7722  ANÁLISE E DESENVOLVIMENTO DE SISTEMAS
# ...

# %% [markdown]
# ## Day 7 - ??
