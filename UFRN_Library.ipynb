# %% [markdown]
# # 7 Days of Code - Alura: Python Pandas

# %% [markdown]
# **Challenger: [Francisco Foz](https://www.linkedin.com/in/francisco-tadeu-foz/?originalSubdomain=br)**

# %% [markdown]
# "Neste #7DaysOfCode, o seu objetivo será explorar os dados de empréstimos dos acervos do sistema de bibliotecas da UFRN.
#
# Você poderá treinar suas habilidades de manipulação, visualização e análise de dados utilizando Python Pandas."
#
# ---
#
# "In this #7DaysOfCode, your goal will be to explore the loan data from the collections of the UFRN library system.
#
# You will be able to train your data manipulation, visualization and analysis skills using Python Pandas."

# %% [markdown]
# ## Day 1 - Data Import

# %% [markdown]
# "Você trabalhará com dados apenas dos últimos 10 anos disponíveis. Por isso, importe para seu Jupyter Notebook os dados de:
#
# 1. [Empréstimos dos acervos das bibliotecas de UFRN](https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/tree/main/Dia_1-Importando_dados/Datasets/dados_emprestimos?utm_source=ActiveCampaign&utm_medium=email&utm_content=%237DaysOfCode+-+Python+Pandas+1%2F7%3A+Importação+de+dados&utm_campaign=%5BAlura+%237Days+Of+Code%5D%28Python+Pandas+-+1ª+Ed+%29+1%2F7)
# 2. [Exemplares do acervo](https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet?utm_source=ActiveCampaign&utm_medium=email&utm_content=%237DaysOfCode+-+Python+Pandas+1%2F7%3A+Importação+de+dados&utm_campaign=%5BAlura+%237Days+Of+Code%5D%28Python+Pandas+-+1ª+Ed+%29+1%2F7)"
#
#
# ---
#
# "You will work with data only from the last 10 years available. Therefore, import into your Jupyter Notebook the data from:
#
# 1. [Loans from UFRN library collections](https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/tree/main/Dia_1-Importando_dados/Datasets/dados_emprestimos?utm_source=ActiveCampaign&utm_medium=email&utm_content=%237DaysOfCode+-+Python+Pandas+1%2F7%3A+Importação+de+dados&utm_campaign=%5BAlura+%237Days+Of+Code%5D%28Python+Pandas+-+1ª+Ed+%29+1%2F7)
# 2. [Exemplars from the collection](https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet?utm_source=ActiveCampaign&utm_medium=email&utm_content=%237DaysOfCode+-+Python+Pandas+1%2F7%3A+Importação+de+dados&utm_campaign=%5BAlura+%237Days+Of+Code%5D%28Python+Pandas+-+1ª+Ed+%29+1%2F7)"

# %%
import pandas as pd
import numpy as np

# %%
i = 20
year_filename = ['20201']
for n in range(0,10):
  i -= 1
  year_filename.append('20' + str(i) + '1')
  year_filename.append('20' + str(i) + '2')

# %%
dataframes = []

for i in year_filename:
  year = ''.join(list(i)[:-1])

  df = pd.read_csv(f'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-{i}.csv', sep=',')
  df['Ano'] = year

  dataframes.append(df)

# %%
merged_df = pd.concat(dataframes).sort_values('Ano')

# %%
loans = merged_df

# %%
loans.shape
# Out:
# (2258018, 8)

# %%
loans.isnull().sum()
# Out:
# id_emprestimo                 0
# codigo_barras                 0
# data_renovacao          1285720
# data_emprestimo               0
# data_devolucao             6471
# matricula_ou_siape         3170
# tipo_vinculo_usuario          0
# Ano                           0
# dtype: int64

# %%
loans.drop_duplicates()
# Out:
#         id_emprestimo codigo_barras                 data_renovacao  \
# 100695         920245       S024938                            NaN
# 65353          775130       L182873                            NaN
# 65352          775129       L133635                            NaN
# 65351          775128    2009004378                            NaN
# 65350          775127       L167802                            NaN
# ...               ...           ...                            ...
# 17711         2980236    2014074503                            NaN
# 17712         2980237    2008048974                            NaN
# 17713         2980238    2013084538  2020/03/29 11:42:46.802000000
# 17703         2980228    2011021607  2020/03/24 18:02:17.352000000
# 0             2962509    2007005628                            NaN
#
#                       data_emprestimo                 data_devolucao  \
# 100695  2010/12/30 16:52:19.891000000  2011/01/14 10:33:04.000000000
# ...

# %% [markdown]
# Reading Apache Parquet

# %%
collections = pd.read_parquet('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet')

# %%
collections
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %%
collections[['registro_sistema', 'id_exemplar', 'codigo_barras']].drop_duplicates(inplace=True)
# Out:
# <ipython-input-11-e50c187f0fc7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   collections[['registro_sistema', 'id_exemplar', 'codigo_barras']].drop_duplicates(inplace=True)

# %%
collections
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %%
collections.isnull().sum()
# Out:
# id_exemplar         0
# codigo_barras       0
# colecao             0
# biblioteca          0
# status_material     0
# localizacao         0
# registro_sistema    0
# dtype: int64

# %%
dataframes = [loans, collections]
merged_df = pd.concat(dataframes).sort_values('codigo_barras')

# %%
merged_df.sample(3)
# Out:
#         id_emprestimo codigo_barras data_renovacao  \
# 41972        962229.0       C024026            NaN
# 177507            NaN   2007027534A            NaN
# 17267       1790126.0    2013085084            NaN
#
#                       data_emprestimo                 data_devolucao  \
# 41972   2011/03/31 20:50:56.693000000  2011/04/07 21:51:33.000000000
# 177507                            NaN                            NaN
# 17267   2014/07/30 10:00:39.772000000  2014/08/05 16:03:05.000000000
#
#         matricula_ou_siape tipo_vinculo_usuario   Ano  id_exemplar  \
# 41972         2.009061e+09   ALUNO DE GRADUAÇÃO  2011          NaN
# 177507                 NaN                  NaN   NaN     186715.0
# 17267         2.011017e+09   ALUNO DE GRADUAÇÃO  2014          NaN
#
#            colecao                                         biblioteca  \
# 41972          NaN                                                NaN
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2804255 entries, 43465 to 53167
# Data columns (total 14 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         float64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
#  7   Ano                   object
#  8   id_exemplar           float64
#  9   colecao               object
#  10  biblioteca            object
#  11  status_material       object
#  12  localizacao           float64
#  13  registro_sistema      float64
# dtypes: float64(5), object(9)
# memory usage: 320.9+ MB

# %%
merged_df.isnull().sum()
# Out:
# id_emprestimo            546237
# codigo_barras                 0
# data_renovacao          1831957
# data_emprestimo          546237
# data_devolucao           552708
# matricula_ou_siape       549407
# tipo_vinculo_usuario     546237
# Ano                      546237
# id_exemplar             2258018
# colecao                 2258018
# biblioteca              2258018
# status_material         2258018
# localizacao             2258018
# registro_sistema        2258018
# dtype: int64

# %%
merged_df.sample(5)
# Out:
#         id_emprestimo codigo_barras                 data_renovacao  \
# 20203       1555413.0    2007028487  2013/08/19 20:00:42.524000000
# 109908      1259787.0    2011083775                            NaN
# 66803        866170.0    2007028487                            NaN
# 99396       9803352.0       Y008695                            NaN
# 387714            NaN    2012033093                            NaN
#
#                       data_emprestimo                 data_devolucao  \
# 20203   2013/08/05 08:51:21.789000000  2013/08/23 08:40:48.000000000
# 109908  2012/05/24 20:26:31.164000000  2012/05/29 14:40:07.000000000
# 66803   2010/11/03 20:17:53.004000000  2010/11/08 19:29:32.000000000
# 99396   2017/05/30 20:45:53.337000000  2017/06/13 21:35:57.000000000
# 387714                            NaN                            NaN
#
#         matricula_ou_siape tipo_vinculo_usuario   Ano  id_exemplar  \
# 20203         2.011032e+09   ALUNO DE GRADUAÇÃO  2013          NaN
# ...

# %%
merged_df.isnull().sum()
# Out:
# id_emprestimo            546237
# codigo_barras                 0
# data_renovacao          1831957
# data_emprestimo          546237
# data_devolucao           552708
# matricula_ou_siape       549407
# tipo_vinculo_usuario     546237
# Ano                      546237
# id_exemplar             2258018
# colecao                 2258018
# biblioteca              2258018
# status_material         2258018
# localizacao             2258018
# registro_sistema        2258018
# dtype: int64

# %%
merged_df.sample(10)
# Out:
#         id_emprestimo codigo_barras                 data_renovacao  \
# 487373            NaN    2017003880                            NaN
# 288893            NaN    2011065713                            NaN
# 77426       1227253.0    2008015255                            NaN
# 85879       9749264.0    2011033127  2017/05/25 12:45:30.754000000
# 2013        1537196.0       L200438  2013/08/04 14:35:42.841000000
# 372367            NaN    2012014610                            NaN
# 70285        869652.0       S023344  2010/11/24 20:54:05.823000000
# 30841       2382254.0    2008037866                            NaN
# 76335       1849453.0        000981  2014/10/20 23:58:15.749000000
# 103446      1132374.0       L178439                            NaN
#
#                       data_emprestimo                 data_devolucao  \
# 487373                            NaN                            NaN
# 288893                            NaN                            NaN
# ...

# %% [markdown]
# ## Day 2 - Data cleaning

# %% [markdown]
# "Você irá iniciar a limpeza e atribuir mais contexto aos seus dados para depois aprofundar-se nas análises"
#
# ---
#
#
# "You'll start cleaning up and giving more context to your data, then dig deeper into analytics."

# %% [markdown]
# "Crie uma nova coluna com os valores da localização, para refletir a respectiva classe geral na CDU."
#
#
# ---
#
# "Create a new column with location values ​​to reflect the respective overall class in the CDU."

# %% [markdown]
# "Você precisará ainda excluir alguns dados e modificar outros."
#
# ---
#
# "You will still need to delete some data and modify others."

# %%
merged_df.columns
# Out:
# Index(['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo',
#        'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario', 'Ano',
#        'id_exemplar', 'colecao', 'biblioteca', 'status_material',
#        'localizacao', 'registro_sistema'],
#       dtype='object')

# %%
df = merged_df[['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo', 'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario', 'Ano', 'id_exemplar', 'colecao', 'biblioteca', 'status_material', 'localizacao']]

# %%
def map_cdu_classification(value):
    if 0 <= value < 100:
        return 'Generalidades. Ciência e conhecimento'
    elif 100 <= value < 200:
        return 'Filosofia e psicologia'
    elif 200 <= value < 300:
        return 'Religião'
    elif 300 <= value < 400:
        return 'Ciências sociais'
    elif 400 <= value < 500:
        return 'Classe vaga. Provisoriamente não ocupada'
    elif 500 <= value < 600:
        return 'Matemática e ciências naturais'
    elif 600 <= value < 700:
        return 'Ciências aplicadas'
    elif 700 <= value < 800:
        return 'Belas artes'
    elif 800 <= value < 900:
        return 'Linguagem. Língua. Linguística'
    elif 900 <= value < 1000:
        return 'Geografia. Biografia. História'
    else:
        return ''

df['CDU'] = df[df['localizacao'].notnull()]['localizacao'].astype(int).map(map_cdu_classification)

# %%
df['matricula_ou_siape'] = df['matricula_ou_siape'].fillna('Não computado').astype(str)

# %%
df
# Out:
#         id_emprestimo                      codigo_barras data_renovacao  \
# 43465             NaN  0000000000000_15/08/2018 12:16:21            NaN
# 160363            NaN        0000000_15/08/2018 12:16:11            NaN
# 270326            NaN                             000001            NaN
# 270327            NaN                             000002            NaN
# 270328            NaN                             000003            NaN
# ...               ...                                ...            ...
# 221077            NaN                            Z099627            NaN
# 223330            NaN                            Z099945            NaN
# 50819        760579.0                            Z099945            NaN
# 6570         716242.0                            Z099945            NaN
# 53167        762929.0                            Z099945            NaN
#
#                       data_emprestimo                 data_devolucao  \
# ...

# %%
df.sample(10)
# Out:
#         id_emprestimo codigo_barras                 data_renovacao  \
# 528458            NaN    2017011621                            NaN
# 471510            NaN    2018030594                            NaN
# 212370            NaN    2007018551                            NaN
# 4469         714141.0    2009022190  2010/02/08 17:49:08.635000000
# 43072             NaN    2014019300                            NaN
# 35090        955345.0    2010002201  2011/04/10 10:10:37.976000000
# 53369       2404787.0    2012036713  2016/05/02 06:38:50.311000000
# 17150       2039312.0    2010049855                            NaN
# 31397       2382810.0    2016025767                            NaN
# 13428        933678.0       C003431                            NaN
#
#                       data_emprestimo                 data_devolucao  \
# 528458                            NaN                            NaN
# 471510                            NaN                            NaN
# ...

# %% [markdown]
# ## Day 3 - ??

# %% [markdown]
# ## Day 4 - ??

# %% [markdown]
# ## Day 5 - ??

# %% [markdown]
# ## Day 6 - ??

# %% [markdown]
# ## Day 7 - ??
